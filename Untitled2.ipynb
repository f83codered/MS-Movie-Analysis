# %%
import pandas as pd

# %%
# basics dataframe will be used as a guide linking the others since it is the only
# one that has genres and lenght of movies
basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
# first 2 rows
basics.head(2)
# Out:
#       tconst                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres
# 0            175.0  Action,Crime,Drama
# 1            114.0     Biography,Drama

# %%
# last 2 rows
basics.tail(2)
# Out:
#            tconst                   primary_title  \
# 146142  tt9916730                          6 Gunn
# 146143  tt9916754  Chico Albuquerque - Revelações
#
#                         original_title  start_year  runtime_minutes  \
# 146142                          6 Gunn        2017            116.0
# 146143  Chico Albuquerque - Revelações        2013              NaN
#
#              genres
# 146142          NaN
# 146143  Documentary

# %%
# general shape of the dataset
basics.shape
# Out:
# (146144, 6)

# %%
# general info of the dataset
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# checking genres column
basics.genres.unique()
# Out:
# array(['Action,Crime,Drama', 'Biography,Drama', 'Drama', ...,
#        'Music,Musical,Reality-TV', 'Animation,Crime',
#        'Adventure,History,War'], dtype=object)

# %%
# checking count of genres
basics['genres'].value_counts()
# Out:
# Documentary                     32185
# Drama                           21486
# Comedy                           9177
# Horror                           4372
# Comedy,Drama                     3519
#                                 ...
# Documentary,Reality-TV,Sport        1
# Action,Horror,Music                 1
# Action,Adventure,Musical            1
# Adventure,Horror,Western            1
# Documentary,Music,Reality-TV        1
# Name: genres, Length: 1085, dtype: int64

# %%
# checking 10 most common genres
basics['genres'].value_counts()[:10]
# Out:
# Documentary              32185
# Drama                    21486
# Comedy                    9177
# Horror                    4372
# Comedy,Drama              3519
# Thriller                  3046
# Action                    2219
# Biography,Documentary     2115
# Drama,Romance             2079
# Comedy,Drama,Romance      1558
# Name: genres, dtype: int64

# %%
# ratings dataframe will give us an insight into public opinion
ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
# first 2 rows
ratings.head(5)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# last 5 rows
ratings.tail(5)
# Out:
#           tconst  averagerating  numvotes
# 73851  tt9805820            8.1        25
# 73852  tt9844256            7.5        24
# 73853  tt9851050            4.7        14
# 73854  tt9886934            7.0         5
# 73855  tt9894098            6.3       128

# %%
# checking a random sample of the dataset
ratings.sample(10)
# Out:
#           tconst  averagerating  numvotes
# 30963  tt3385516            7.0    356556
# 29174  tt2252270            5.9         7
# 5906   tt9581172            7.1       146
# 19524  tt8443432            5.8        91
# 17620  tt1837494            7.1       175
# 32840  tt2883794            7.1         7
# 71572  tt1675846            4.7        27
# 55195  tt2415536            4.6         8
# 68206  tt4287344            6.5        17
# 26570  tt3811932            7.2        16

# %%
# checking columns
ratings.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
# general dataset info
# Note: rows without empty values
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# statistical overview of ratings dataset
ratings.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
# sorting the dataset by 'averagerating'
ratings.sort_values('averagerating', ascending = False)
# Out:
#           tconst  averagerating  numvotes
# 27644  tt8730716           10.0         5
# 8992   tt1770682           10.0         5
# 26153  tt2632430           10.0         5
# 65033  tt9715646           10.0        20
# 57679  tt5344358           10.0         6
# ...          ...            ...       ...
# 50971  tt6017238            1.0        21
# 32440  tt2087999            1.0         7
# 36456  tt1896768            1.0        21
# 54856  tt1976600            1.0       436
# 39248  tt8654080            1.0        21
#
# [73856 rows x 3 columns]

# %%
# general overview of 'averagerating'
ratings['averagerating'].unique()
# Out:
# array([ 8.3,  8.9,  6.4,  4.2,  6.5,  6.2,  7. ,  7.2,  5.1,  5.8,  8. ,
#         5.5,  7.6,  5. ,  7.4,  6.6,  5.4,  4. ,  4.4,  5.6,  6.1,  3.4,
#         7.7,  4.5,  6.3,  6.7,  8.4,  7.8,  5.2,  3.6,  2.1,  2.5,  4.6,
#         7.5,  5.7,  3.5,  7.1,  8.5,  5.3,  8.2,  3.8,  4.9,  6.9,  8.6,
#         7.3,  4.7,  3.2,  2.6,  3.9,  5.9,  8.7,  6.8,  7.9,  2. ,  6. ,
#         3.7,  2.4,  3. ,  8.1,  4.8,  2.8,  9.2,  4.3,  2.9,  4.1,  1.4,
#         1.9,  8.8,  9.4,  3.3,  9.1,  9.7,  9. ,  2.7,  1. ,  3.1,  1.7,
#         2.3,  9.5,  9.3,  2.2,  1.2,  1.1,  9.8,  1.8,  1.5,  9.6,  1.6,
#         9.9,  1.3, 10. ])

# %%
# roi dataframe will be important to give us an insight on movies with successfull returns of investment
roidf = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
roidf
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
# Converting 'production_budget' and 'worldwide_gross' columns to numeric values
roidf['production_budget'] = roidf['production_budget'].str.replace('$', '').str.replace(',', '').astype(float)
roidf['worldwide_gross'] = roidf['worldwide_gross'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
roidf['roi'] = roidf['worldwide_gross']/roidf['production_budget'] * 100

# %%
# dataset with created column 'roi'
roidf
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross           roi
# 0           425000000.0   $760,507,625     2.776345e+09    653.257713
# 1           410600000.0   $241,063,875     1.045664e+09    254.667286
# 2           350000000.0    $42,762,350     1.497624e+08     42.789243
# 3           330600000.0   $459,005,868     1.403014e+09    424.384139
# 4           317000000.0   $620,181,382     1.316722e+09    415.369636
# ...                 ...            ...              ...           ...
# 5777             7000.0             $0     0.000000e+00      0.000000
# 5778             6000.0        $48,482     2.404950e+05   4008.250000
# 5779             5000.0         $1,338     1.338000e+03     26.760000
# 5780             1400.0             $0     0.000000e+00      0.000000
# 5781             1100.0       $181,041     1.810410e+05  16458.272727
#
# [5782 rows x 7 columns]

# %%
# sorting roidf in descending order to check profitable movies
roidf1 = roidf[roidf['roi'] > 0].sort_values(by='roi', ascending=False)
roidf1
# Out:
#       id  release_date                           movie  production_budget  \
# 5745  46  Jun 30, 1972                     Deep Throat            25000.0
# 5613  14  Mar 21, 1980                         Mad Max           200000.0
# 5492  93  Sep 25, 2009             Paranormal Activity           450000.0
# 5679  80  Jul 10, 2015                     The Gallows           100000.0
# 5406   7  Jul 14, 1999         The Blair Witch Project           600000.0
# ...   ..           ...                             ...                ...
# 5335  36  Nov 21, 2014                     Food Chains           913000.0
# 2152  53  Aug 24, 1997  The Grimm Brothers' Snow White         26000000.0
# 3818  19   May 8, 2015                      Skin Trade          9000000.0
# 4081  82  May 21, 2010              Perrierâs Bounty          6600000.0
# 5302   3  Dec 11, 2015                   American Hero          1000000.0
#
#      domestic_gross  worldwide_gross            roi
# 5745    $45,000,000       45000000.0  180000.000000
# 5613     $8,750,000       99750000.0   49875.000000
# 5492   $107,918,810      194183034.0   43151.785333
# 5679    $22,764,410       41656474.0   41656.474000
# 5406   $140,539,099      248300000.0   41383.333333
# ...             ...              ...            ...
# 5335             $0            176.0       0.019277
# 2152         $5,000           5000.0       0.019231
# 3818         $1,242           1242.0       0.013800
# 4081           $828            828.0       0.012545
# 5302             $0             26.0       0.002600
#
# [5415 rows x 7 columns]

# %%
# dropping column 'domestic_gross'
roidf2 = roidf1.drop(columns = 'domestic_gross')
roidf2
# Out:
#       id  release_date                           movie  production_budget  \
# 5745  46  Jun 30, 1972                     Deep Throat            25000.0
# 5613  14  Mar 21, 1980                         Mad Max           200000.0
# 5492  93  Sep 25, 2009             Paranormal Activity           450000.0
# 5679  80  Jul 10, 2015                     The Gallows           100000.0
# 5406   7  Jul 14, 1999         The Blair Witch Project           600000.0
# ...   ..           ...                             ...                ...
# 5335  36  Nov 21, 2014                     Food Chains           913000.0
# 2152  53  Aug 24, 1997  The Grimm Brothers' Snow White         26000000.0
# 3818  19   May 8, 2015                      Skin Trade          9000000.0
# 4081  82  May 21, 2010              Perrierâs Bounty          6600000.0
# 5302   3  Dec 11, 2015                   American Hero          1000000.0
#
#       worldwide_gross            roi
# 5745       45000000.0  180000.000000
# 5613       99750000.0   49875.000000
# 5492      194183034.0   43151.785333
# 5679       41656474.0   41656.474000
# 5406      248300000.0   41383.333333
# ...               ...            ...
# 5335            176.0       0.019277
# 2152           5000.0       0.019231
# 3818           1242.0       0.013800
# 4081            828.0       0.012545
# 5302             26.0       0.002600
#
# [5415 rows x 6 columns]

# %%
# for this analysis, we don't need the full release date
# we want to convert the release date to year only format
# converting 'release_date' column to datetime format
roidf2['release_date'] = pd.to_datetime(roidf2['release_date'])

# extracting the year from 'release_date' column
roidf2['release_date'] = roidf2['release_date'].dt.year

roidf2
# Out:
#       id  release_date                           movie  production_budget  \
# 5745  46          1972                     Deep Throat            25000.0
# 5613  14          1980                         Mad Max           200000.0
# 5492  93          2009             Paranormal Activity           450000.0
# 5679  80          2015                     The Gallows           100000.0
# 5406   7          1999         The Blair Witch Project           600000.0
# ...   ..           ...                             ...                ...
# 5335  36          2014                     Food Chains           913000.0
# 2152  53          1997  The Grimm Brothers' Snow White         26000000.0
# 3818  19          2015                      Skin Trade          9000000.0
# 4081  82          2010              Perrierâs Bounty          6600000.0
# 5302   3          2015                   American Hero          1000000.0
#
#       worldwide_gross            roi
# 5745       45000000.0  180000.000000
# 5613       99750000.0   49875.000000
# 5492      194183034.0   43151.785333
# 5679       41656474.0   41656.474000
# 5406      248300000.0   41383.333333
# ...               ...            ...
# 5335            176.0       0.019277
# 2152           5000.0       0.019231
# 3818           1242.0       0.013800
# 4081            828.0       0.012545
# 5302             26.0       0.002600
#
# [5415 rows x 6 columns]

# %%
roidf2.rename(columns={'movie': 'primary_title'}, inplace=True)

# %%
roidf2
# Out:
#       id  release_date                   primary_title  production_budget  \
# 5745  46          1972                     Deep Throat            25000.0
# 5613  14          1980                         Mad Max           200000.0
# 5492  93          2009             Paranormal Activity           450000.0
# 5679  80          2015                     The Gallows           100000.0
# 5406   7          1999         The Blair Witch Project           600000.0
# ...   ..           ...                             ...                ...
# 5335  36          2014                     Food Chains           913000.0
# 2152  53          1997  The Grimm Brothers' Snow White         26000000.0
# 3818  19          2015                      Skin Trade          9000000.0
# 4081  82          2010              Perrierâs Bounty          6600000.0
# 5302   3          2015                   American Hero          1000000.0
#
#       worldwide_gross            roi
# 5745       45000000.0  180000.000000
# 5613       99750000.0   49875.000000
# 5492      194183034.0   43151.785333
# 5679       41656474.0   41656.474000
# 5406      248300000.0   41383.333333
# ...               ...            ...
# 5335            176.0       0.019277
# 2152           5000.0       0.019231
# 3818           1242.0       0.013800
# 4081            828.0       0.012545
# 5302             26.0       0.002600
#
# [5415 rows x 6 columns]

# %%
# general statistics distribution
roidf2.describe()
# Out:
#                 id  release_date  production_budget  worldwide_gross  \
# count  5415.000000   5415.000000       5.415000e+03     5.415000e+03
# mean     50.227701   2003.599446       3.330801e+07     9.768800e+07
# std      28.765167     12.546965       4.248758e+07     1.788591e+08
# min       1.000000   1915.000000       1.100000e+03     2.600000e+01
# 25%      25.000000   1999.000000       6.000000e+06     7.004834e+06
# 50%      50.000000   2006.000000       1.900000e+07     3.333987e+07
# 75%      75.000000   2012.000000       4.200000e+07     1.044590e+08
# max     100.000000   2019.000000       4.250000e+08     2.776345e+09
#
#                  roi
# count    5415.000000
# mean      512.549086
# std      3048.742025
# min         0.002600
# 25%        70.105162
# 50%       188.492114
# 75%       396.878000
# max    180000.000000

# %%
# merging basics and ratings datasets
merge_1 = pd.merge(ratings, basics, on = 'tconst')

# %%
# checking first rows
merge_1.head(20)
# Out:
#         tconst  averagerating  numvotes  \
# 0   tt10356526            8.3        31
# 1   tt10384606            8.9       559
# 2    tt1042974            6.4        20
# 3    tt1043726            4.2     50352
# 4    tt1060240            6.5        21
# 5    tt1069246            6.2       326
# 6    tt1094666            7.0      1613
# 7    tt1130982            6.4       571
# 8    tt1156528            7.2       265
# 9    tt1161457            4.2       148
# 10   tt1171222            5.1      8296
# 11   tt1174693            5.8      2381
# 12   tt1181840            7.0      5494
# 13   tt1193623            8.0         5
# 14   tt1199588            5.5        74
# 15   tt1204784            5.8         6
# 16   tt1210166            7.6    326657
# 17   tt1212419            6.5     87288
# 18   tt1220911            5.0       941
# 19   tt1229238            7.4    428142
#
#                                         primary_title  \
# 0                                    Laiye Je Yaarian
# 1                                          Borderless
# 2                                           Just Inès
# 3                              The Legend of Hercules
# 4                                           Até Onde?
# 5                                          Habana Eva
# 6                                          The Hammer
# 7                                     The Night Clerk
# 8                                       Silent Sonata
# 9                                          Vanquisher
# 10                                      Baggage Claim
# 11                                The Four-Faced Liar
# 12                    Jack and the Cuckoo-Clock Heart
# 13                                     Buried Prayers
# 14                                        Black Widow
# 15  Maverick and Ariel's First Ever Ever Movie Hol...
# 16                                          Moneyball
# 17                                          Hereafter
# 18                      Why I Did (Not) Eat My Father
# 19               Mission: Impossible - Ghost Protocol
#
#                                        original_title  start_year  \
# 0                                    Laiye Je Yaarian        2019
# 1                                          Borderless        2019
# 2                                           Just Inès        2010
# 3                              The Legend of Hercules        2014
# 4                                           Até Onde?        2011
# 5                                          Habana Eva        2010
# 6                                              Hamill        2010
# 7                                        Avant l'aube        2011
# 8                                  Circus Fantasticus        2011
# 9                                      The Vanquisher        2016
# 10                                      Baggage Claim        2013
# 11                                The Four-Faced Liar        2010
# 12                      Jack et la mécanique du coeur        2013
# 13                                     Buried Prayers        2010
# 14                                        Black Widow        2010
# 15  Maverick and Ariel's First Ever Ever Movie Hol...        2010
# 16                                          Moneyball        2011
# 17                                          Hereafter        2010
# 18                   Pourquoi j'ai pas mangé mon père        2015
# 19               Mission: Impossible - Ghost Protocol        2011
#
#     runtime_minutes                      genres
# 0             117.0                     Romance
# 1              87.0                 Documentary
# 2              90.0                       Drama
# 3              99.0    Action,Adventure,Fantasy
# 4              73.0            Mystery,Thriller
# 5             106.0              Comedy,Romance
# 6             108.0       Biography,Drama,Sport
# 7             104.0              Drama,Thriller
# 8              77.0                   Drama,War
# 9              90.0     Action,Adventure,Sci-Fi
# 10             96.0                      Comedy
# 11             87.0        Comedy,Drama,Romance
# 12             94.0   Adventure,Animation,Drama
# 13              NaN                 Documentary
# 14             75.0                    Thriller
# 15              NaN                      Comedy
# 16            133.0       Biography,Drama,Sport
# 17            129.0       Drama,Fantasy,Romance
# 18            101.0  Adventure,Animation,Comedy
# 19            132.0   Action,Adventure,Thriller

# %%
merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   averagerating    73856 non-null   float64
#  2   numvotes         73856 non-null   float64
#  3   primary_title    146144 non-null  object
#  4   original_title   146123 non-null  object
#  5   start_year       146144 non-null  int64
#  6   runtime_minutes  114405 non-null  float64
#  7   genres           140736 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
# merging roidf2 dataset to merge1 
roi_merge = pd.merge(merge1, roidf2, on = 'primary_title', how = 'outer')

# %%
roi_merge.head(20)
# Out:
#         tconst  averagerating  numvotes  \
# 0   tt10356526            8.3      31.0
# 1   tt10384606            8.9     559.0
# 2    tt4131210            7.1     210.0
# 3    tt1042974            6.4      20.0
# 4    tt1043726            4.2   50352.0
# 5    tt1060240            6.5      21.0
# 6    tt1069246            6.2     326.0
# 7    tt1094666            7.0    1613.0
# 8    tt3096900            6.5      13.0
# 9    tt1130982            6.4     571.0
# 10   tt1156528            7.2     265.0
# 11   tt1161457            4.2     148.0
# 12   tt1171222            5.1    8296.0
# 13   tt1174693            5.8    2381.0
# 14   tt1181840            7.0    5494.0
# 15   tt1193623            8.0       5.0
# 16   tt1199588            5.5      74.0
# 17   tt9158074            NaN       NaN
# 18   tt1204784            5.8       6.0
# 19   tt1210166            7.6  326657.0
#
#                                         primary_title  \
# 0                                    Laiye Je Yaarian
# 1                                          Borderless
# 2                                          Borderless
# 3                                           Just Inès
# 4                              The Legend of Hercules
# 5                                           Até Onde?
# 6                                          Habana Eva
# 7                                          The Hammer
# 8                                          The Hammer
# 9                                     The Night Clerk
# 10                                      Silent Sonata
# 11                                         Vanquisher
# 12                                      Baggage Claim
# 13                                The Four-Faced Liar
# 14                    Jack and the Cuckoo-Clock Heart
# 15                                     Buried Prayers
# 16                                        Black Widow
# 17                                        Black Widow
# 18  Maverick and Ariel's First Ever Ever Movie Hol...
# 19                                          Moneyball
#
#                                        original_title  start_year  \
# 0                                    Laiye Je Yaarian      2019.0
# 1                                          Borderless      2019.0
# 2                                         Bedone marz      2014.0
# 3                                           Just Inès      2010.0
# 4                              The Legend of Hercules      2014.0
# 5                                           Até Onde?      2011.0
# 6                                          Habana Eva      2010.0
# 7                                              Hamill      2010.0
# 8                                          The Hammer      2015.0
# 9                                        Avant l'aube      2011.0
# 10                                 Circus Fantasticus      2011.0
# 11                                     The Vanquisher      2016.0
# 12                                      Baggage Claim      2013.0
# 13                                The Four-Faced Liar      2010.0
# 14                      Jack et la mécanique du coeur      2013.0
# 15                                     Buried Prayers      2010.0
# 16                                        Black Widow      2010.0
# 17                                        Black Widow      2017.0
# 18  Maverick and Ariel's First Ever Ever Movie Hol...      2010.0
# 19                                          Moneyball      2011.0
#
#     runtime_minutes                        genres    id  release_date  \
# 0             117.0                       Romance   NaN           NaN
# 1              87.0                   Documentary   NaN           NaN
# 2             102.0                     Drama,War   NaN           NaN
# 3              90.0                         Drama   NaN           NaN
# 4              99.0      Action,Adventure,Fantasy  42.0        2014.0
# 5              73.0              Mystery,Thriller   NaN           NaN
# 6             106.0                Comedy,Romance   NaN           NaN
# 7             108.0         Biography,Drama,Sport  50.0        2008.0
# 8              75.0  Action,Adventure,Documentary  50.0        2008.0
# 9             104.0                Drama,Thriller   NaN           NaN
# 10             77.0                     Drama,War   NaN           NaN
# 11             90.0       Action,Adventure,Sci-Fi   NaN           NaN
# 12             96.0                        Comedy  38.0        2013.0
# 13             87.0          Comedy,Drama,Romance   NaN           NaN
# 14             94.0     Adventure,Animation,Drama   NaN           NaN
# 15              NaN                   Documentary   NaN           NaN
# 16             75.0                      Thriller   NaN           NaN
# 17              NaN                         Drama   NaN           NaN
# 18              NaN                        Comedy   NaN           NaN
# 19            133.0         Biography,Drama,Sport  15.0        2011.0
#
#     production_budget  worldwide_gross         roi
# 0                 NaN              NaN         NaN
# 1                 NaN              NaN         NaN
# 2                 NaN              NaN         NaN
# 3                 NaN              NaN         NaN
# 4          70000000.0       58953319.0   84.219027
# 5                 NaN              NaN         NaN
# 6                 NaN              NaN         NaN
# 7            850000.0         442638.0   52.075059
# 8            850000.0         442638.0   52.075059
# 9                 NaN              NaN         NaN
# 10                NaN              NaN         NaN
# 11                NaN              NaN         NaN
# 12          8500000.0       22885836.0  269.245129
# 13                NaN              NaN         NaN
# 14                NaN              NaN         NaN
# 15                NaN              NaN         NaN
# 16                NaN              NaN         NaN
# 17                NaN              NaN         NaN
# 18                NaN              NaN         NaN
# 19         50000000.0      111300835.0  222.601670

# %%
roi_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149569 entries, 0 to 149568
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             146307 non-null  object
#  1   averagerating      73958 non-null   float64
#  2   numvotes           73958 non-null   float64
#  3   primary_title      149569 non-null  object
#  4   original_title     146286 non-null  object
#  5   start_year         146307 non-null  float64
#  6   runtime_minutes    114544 non-null  float64
#  7   genres             140896 non-null  object
#  8   id                 6707 non-null    float64
#  9   release_date       6707 non-null    float64
#  10  production_budget  6707 non-null    float64
#  11  worldwide_gross    6707 non-null    float64
#  12  roi                6707 non-null    float64
# dtypes: float64(9), object(4)
# memory usage: 16.0+ MB

# %%
columns_to_drop = ['original_title', 'id', 'release_date']
roi_short = roi_merge.drop(columns=columns_to_drop)
roi_short.head()
# Out:
#        tconst  averagerating  numvotes           primary_title  start_year  \
# 0  tt10356526            8.3      31.0        Laiye Je Yaarian      2019.0
# 1  tt10384606            8.9     559.0              Borderless      2019.0
# 2   tt4131210            7.1     210.0              Borderless      2014.0
# 3   tt1042974            6.4      20.0               Just Inès      2010.0
# 4   tt1043726            4.2   50352.0  The Legend of Hercules      2014.0
#
#    runtime_minutes                    genres  production_budget  \
# 0            117.0                   Romance                NaN
# 1             87.0               Documentary                NaN
# 2            102.0                 Drama,War                NaN
# 3             90.0                     Drama                NaN
# 4             99.0  Action,Adventure,Fantasy         70000000.0
#
#    worldwide_gross        roi
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4       58953319.0  84.219027

# %%
roi_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149569 entries, 0 to 149568
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             146307 non-null  object
#  1   averagerating      73958 non-null   float64
#  2   numvotes           73958 non-null   float64
#  3   primary_title      149569 non-null  object
#  4   start_year         146307 non-null  float64
#  5   runtime_minutes    114544 non-null  float64
#  6   genres             140896 non-null  object
#  7   production_budget  6707 non-null    float64
#  8   worldwide_gross    6707 non-null    float64
#  9   roi                6707 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 12.6+ MB

# %%
# creating a variable to find current year
current_year = pd.Timestamp.now().year
current_year
# Out:
# 2024

# %%
# using above variable to limit dataframe to last 10 years
merge_final = roi_short[roi_short['start_year'] >= current_year - 10]
merge_final
# Out:
#             tconst  averagerating  numvotes  \
# 0       tt10356526            8.3      31.0
# 1       tt10384606            8.9     559.0
# 2        tt4131210            7.1     210.0
# 4        tt1043726            4.2   50352.0
# 8        tt3096900            6.5      13.0
# ...            ...            ...       ...
# 146300   tt9916190            NaN       NaN
# 146301   tt9916428            NaN       NaN
# 146302   tt9916538            NaN       NaN
# 146303   tt9916622            NaN       NaN
# 146305   tt9916730            NaN       NaN
#
#                                       primary_title  start_year  \
# 0                                  Laiye Je Yaarian      2019.0
# 1                                        Borderless      2019.0
# 2                                        Borderless      2014.0
# 4                            The Legend of Hercules      2014.0
# 8                                        The Hammer      2015.0
# ...                                             ...         ...
# 146300                                    Safeguard      2019.0
# 146301                          The Secret of China      2019.0
# 146302                          Kuambil Lagi Hatiku      2019.0
# 146303  Rodolpho Teóphilo - O Legado de um Pioneiro      2015.0
# 146305                                       6 Gunn      2017.0
#
#         runtime_minutes                        genres  production_budget  \
# 0                 117.0                       Romance                NaN
# 1                  87.0                   Documentary                NaN
# 2                 102.0                     Drama,War                NaN
# 4                  99.0      Action,Adventure,Fantasy         70000000.0
# 8                  75.0  Action,Adventure,Documentary           850000.0
# ...                 ...                           ...                ...
# 146300             90.0                Drama,Thriller                NaN
# 146301              NaN         Adventure,History,War                NaN
# 146302            123.0                         Drama                NaN
# 146303              NaN                   Documentary                NaN
# 146305            116.0                           NaN                NaN
#
#         worldwide_gross        roi
# 0                   NaN        NaN
# 1                   NaN        NaN
# 2                   NaN        NaN
# 4            58953319.0  84.219027
# 8              442638.0  52.075059
# ...                 ...        ...
# 146300              NaN        NaN
# 146301              NaN        NaN
# 146302              NaN        NaN
# 146303              NaN        NaN
# 146305              NaN        NaN
#
# [93009 rows x 10 columns]

# %%
# finding NaN values in common
merge_final.isna().sum()
# Out:
# tconst                   0
# averagerating        48937
# numvotes             48937
# primary_title            0
# start_year               0
# runtime_minutes      22918
# genres                3704
# production_budget    90945
# worldwide_gross      90945
# roi                  90945
# dtype: int64

# %%
# eliminating NaN values in 'averagerating', 'numvotes' columns
merge_final.dropna(subset=['averagerating','numvotes'])
# Out:
#            tconst  averagerating  numvotes  \
# 0      tt10356526            8.3      31.0
# 1      tt10384606            8.9     559.0
# 2       tt4131210            7.1     210.0
# 4       tt1043726            4.2   50352.0
# 8       tt3096900            6.5      13.0
# ...           ...            ...       ...
# 79021   tt9768966            8.6      27.0
# 79022   tt9783738            7.4       7.0
# 79023   tt9805820            8.1      25.0
# 79024   tt9844256            7.5      24.0
# 79025   tt9894098            6.3     128.0
#
#                                            primary_title  start_year  \
# 0                                       Laiye Je Yaarian      2019.0
# 1                                             Borderless      2019.0
# 2                                             Borderless      2014.0
# 4                                 The Legend of Hercules      2014.0
# 8                                             The Hammer      2015.0
# ...                                                  ...         ...
# 79021                                         Plugged in      2019.0
# 79022                                 Bangkok Dark Tales      2019.0
# 79023                                              Caisa      2018.0
# 79024  Code Geass: Lelouch of the Rebellion - Glorifi...      2018.0
# 79025                                             Sathru      2019.0
#
#        runtime_minutes                        genres  production_budget  \
# 0                117.0                       Romance                NaN
# 1                 87.0                   Documentary                NaN
# 2                102.0                     Drama,War                NaN
# 4                 99.0      Action,Adventure,Fantasy         70000000.0
# 8                 75.0  Action,Adventure,Documentary           850000.0
# ...                ...                           ...                ...
# 79021             53.0                   Documentary                NaN
# 79022              NaN                        Horror                NaN
# 79023             84.0                   Documentary                NaN
# 79024            120.0       Action,Animation,Sci-Fi                NaN
# 79025            129.0                      Thriller                NaN
#
#        worldwide_gross        roi
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  NaN        NaN
# 4           58953319.0  84.219027
# 8             442638.0  52.075059
# ...                ...        ...
# 79021              NaN        NaN
# 79022              NaN        NaN
# 79023              NaN        NaN
# 79024              NaN        NaN
# 79025              NaN        NaN
#
# [44072 rows x 10 columns]

# %%
# checking for duplicates in 'primary_title'
duplicates = merge_final[merge_final.duplicated(subset = ['primary_title'])]
duplicates
# Out:
#           tconst  averagerating  numvotes        primary_title  start_year  \
# 2      tt4131210            7.1     210.0           Borderless      2014.0
# 56     tt2442620            6.8      93.0              Paradox      2016.0
# 57     tt4540434            4.6    2989.0              Paradox      2016.0
# 58     tt7245176            6.6    2471.0              Paradox      2017.0
# 150    tt4581576            5.7   17992.0            Aftermath      2017.0
# ...          ...            ...       ...                  ...         ...
# 74289  tt1289401            5.2  186788.0         Ghostbusters      2016.0
# 74903  tt5318534            5.6    1137.0  People You May Know      2017.0
# 75246  tt5537018            5.7       6.0                 Coma      2015.0
# 76330  tt2094769            8.0      10.0               Battle      2015.0
# 76744  tt1502712            4.3  140148.0       Fantastic Four      2015.0
#
#        runtime_minutes                  genres  production_budget  \
# 2                102.0               Drama,War                NaN
# 56               103.0    Drama,Romance,Sci-Fi                NaN
# 57                90.0     Action,Drama,Sci-Fi                NaN
# 58               101.0                  Action                NaN
# 150               94.0          Drama,Thriller                NaN
# ...                ...                     ...                ...
# 74289            116.0   Action,Comedy,Fantasy        144000000.0
# 74903             92.0    Comedy,Drama,Romance                NaN
# 75246             97.0             Documentary                NaN
# 76330             65.0                  Action                NaN
# 76744            100.0  Action,Adventure,Drama        120000000.0
#
#        worldwide_gross         roi
# 2                  NaN         NaN
# 56                 NaN         NaN
# 57                 NaN         NaN
# 58                 NaN         NaN
# 150                NaN         NaN
# ...                ...         ...
# 74289      229008658.0  159.033790
# 74903              NaN         NaN
# 75246              NaN         NaN
# 76330              NaN         NaN
# 76744      167849187.0  139.874323
#
# [1628 rows x 10 columns]

# %%
# dropping duplicates to reduce redudancy
merge_final.drop_duplicates(subset='primary_title', keep = "first")
# Out:
#            tconst  averagerating  numvotes  \
# 0      tt10356526            8.3      31.0
# 1      tt10384606            8.9     559.0
# 4       tt1043726            4.2   50352.0
# 8       tt3096900            6.5      13.0
# 11      tt1161457            4.2     148.0
# ...           ...            ...       ...
# 79021   tt9768966            8.6      27.0
# 79022   tt9783738            7.4       7.0
# 79023   tt9805820            8.1      25.0
# 79024   tt9844256            7.5      24.0
# 79025   tt9894098            6.3     128.0
#
#                                            primary_title  start_year  \
# 0                                       Laiye Je Yaarian      2019.0
# 1                                             Borderless      2019.0
# 4                                 The Legend of Hercules      2014.0
# 8                                             The Hammer      2015.0
# 11                                            Vanquisher      2016.0
# ...                                                  ...         ...
# 79021                                         Plugged in      2019.0
# 79022                                 Bangkok Dark Tales      2019.0
# 79023                                              Caisa      2018.0
# 79024  Code Geass: Lelouch of the Rebellion - Glorifi...      2018.0
# 79025                                             Sathru      2019.0
#
#        runtime_minutes                        genres  production_budget  \
# 0                117.0                       Romance                NaN
# 1                 87.0                   Documentary                NaN
# 4                 99.0      Action,Adventure,Fantasy         70000000.0
# 8                 75.0  Action,Adventure,Documentary           850000.0
# 11                90.0       Action,Adventure,Sci-Fi                NaN
# ...                ...                           ...                ...
# 79021             53.0                   Documentary                NaN
# 79022              NaN                        Horror                NaN
# 79023             84.0                   Documentary                NaN
# 79024            120.0       Action,Animation,Sci-Fi                NaN
# 79025            129.0                      Thriller                NaN
#
#        worldwide_gross        roi
# 0                  NaN        NaN
# 1                  NaN        NaN
# 4           58953319.0  84.219027
# 8             442638.0  52.075059
# 11                 NaN        NaN
# ...                ...        ...
# 79021              NaN        NaN
# 79022              NaN        NaN
# 79023              NaN        NaN
# 79024              NaN        NaN
# 79025              NaN        NaN
#
# [42444 rows x 10 columns]

# %%
# we want to find null values in our 'roi' column
merge_final.roi.isna().sum()
# Out:
# 41314

# %%
# this is an important column and we don't want null values
# we will use the median to fill such values
roi_median = merge_final['roi'].median()
roi_median
# Out:
# 195.49729583333334

# %%
# using the median variable 
merge_final['roi'].fillna(roi_median)
# Out:
# 0        195.497296
# 1        195.497296
# 4         84.219027
# 8         52.075059
# 11       195.497296
#             ...
# 79021    195.497296
# 79022    195.497296
# 79023    195.497296
# 79024    195.497296
# 79025    195.497296
# Name: roi, Length: 42444, dtype: float64

# %%
# inspecting the dataframe with 'roi' column without null values
merge_final.head()
# Out:
#         tconst  averagerating  numvotes           primary_title  start_year  \
# 0   tt10356526            8.3      31.0        Laiye Je Yaarian      2019.0
# 1   tt10384606            8.9     559.0              Borderless      2019.0
# 4    tt1043726            4.2   50352.0  The Legend of Hercules      2014.0
# 8    tt3096900            6.5      13.0              The Hammer      2015.0
# 11   tt1161457            4.2     148.0              Vanquisher      2016.0
#
#     runtime_minutes                        genres  production_budget  \
# 0             117.0                       Romance                NaN
# 1              87.0                   Documentary                NaN
# 4              99.0      Action,Adventure,Fantasy         70000000.0
# 8              75.0  Action,Adventure,Documentary           850000.0
# 11             90.0       Action,Adventure,Sci-Fi                NaN
#
#     worldwide_gross         roi
# 0               NaN  195.497296
# 1               NaN  195.497296
# 4        58953319.0   84.219027
# 8          442638.0   52.075059
# 11              NaN  195.497296

# %%
merge_final.tail()
# Out:
#           tconst  averagerating  numvotes  \
# 79021  tt9768966            8.6      27.0
# 79022  tt9783738            7.4       7.0
# 79023  tt9805820            8.1      25.0
# 79024  tt9844256            7.5      24.0
# 79025  tt9894098            6.3     128.0
#
#                                            primary_title  start_year  \
# 79021                                         Plugged in      2019.0
# 79022                                 Bangkok Dark Tales      2019.0
# 79023                                              Caisa      2018.0
# 79024  Code Geass: Lelouch of the Rebellion - Glorifi...      2018.0
# 79025                                             Sathru      2019.0
#
#        runtime_minutes                   genres  production_budget  \
# 79021             53.0              Documentary                NaN
# 79022              NaN                   Horror                NaN
# 79023             84.0              Documentary                NaN
# 79024            120.0  Action,Animation,Sci-Fi                NaN
# 79025            129.0                 Thriller                NaN
#
#        worldwide_gross         roi
# 79021              NaN  195.497296
# 79022              NaN  195.497296
# 79023              NaN  195.497296
# 79024              NaN  195.497296
# 79025              NaN  195.497296

# %%
merge_final.describe()
# Out:
#        averagerating      numvotes    start_year  runtime_minutes  \
# count   42444.000000  4.244400e+04  42444.000000     37886.000000
# mean        6.372338  2.902843e+03   2016.114810        94.619569
# std         1.500784  2.551377e+04      1.506839        25.472764
# min         1.000000  5.000000e+00   2014.000000         3.000000
# 25%         5.500000  1.400000e+01   2015.000000        82.000000
# 50%         6.500000  4.900000e+01   2016.000000        92.000000
# 75%         7.400000  2.700000e+02   2017.000000       105.000000
# max        10.000000  1.299334e+06   2019.000000      1100.000000
#
#        production_budget  worldwide_gross           roi
# count       1.130000e+03     1.130000e+03  42444.000000
# mean        3.915303e+07     1.247177e+08    203.312472
# std         5.066811e+07     2.214129e+08    310.908356
# min         2.500000e+04     2.600000e+01      0.002600
# 25%         7.500000e+06     7.454380e+06    195.497296
# 50%         2.000000e+07     4.220102e+07    195.497296
# 75%         5.000000e+07     1.245447e+08    195.497296
# max         3.500000e+08     2.048134e+09  41656.474000
